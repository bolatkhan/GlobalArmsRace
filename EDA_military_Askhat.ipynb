# %%
# import the necessary libraries you need for your analysis
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# read in csv file and display first 5 rows of datset
world_bank_data = pd.read_csv("data/export_top_1990_2025.csv")
world_bank_data.head()
# Out:
#   Country Name Country Code  \
# 0  Afghanistan          AFG
# 1  Afghanistan          AFG
# 2  Afghanistan          AFG
# 3  Afghanistan          AFG
# 4  Afghanistan          AFG
#
#                                          Series Name        Series Code  \
# 0  Military expenditure (% of general government ...     MS.MIL.XPND.ZS
# 1                    Military expenditure (% of GDP)  MS.MIL.XPND.GD.ZS
# 2        Arms imports (SIPRI trend indicator values)     MS.MIL.MPRT.KD
# 3        Arms exports (SIPRI trend indicator values)     MS.MIL.XPRT.KD
# 4  Government expenditure on education, total (% ...  SE.XPD.TOTL.GB.ZS
#
#   2023 [YR2023] 2022 [YR2022]     2021 [YR2021]     2020 [YR2020]  \
# 0            ..            ..  10.5026598533092  4.97282537449934
# 1            ..            ..    1.827933856217  1.35885692738929
# 2            ..            ..          65000000         234000000
# 3            ..            ..                ..                ..
# ...

# %%
world_bank_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2399 entries, 0 to 2398
# Data columns (total 68 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Country Name   2396 non-null   object
#  1   Country Code   2394 non-null   object
#  2   Series Name    2394 non-null   object
#  3   Series Code    2394 non-null   object
#  4   2023 [YR2023]  2394 non-null   object
#  5   2022 [YR2022]  2394 non-null   object
#  6   2021 [YR2021]  2394 non-null   object
#  7   2020 [YR2020]  2394 non-null   object
#  8   2019 [YR2019]  2394 non-null   object
#  9   2018 [YR2018]  2394 non-null   object
#  10  2017 [YR2017]  2394 non-null   object
#  11  2016 [YR2016]  2394 non-null   object
#  12  2015 [YR2015]  2394 non-null   object
#  13  2014 [YR2014]  2394 non-null   object
#  14  2013 [YR2013]  2394 non-null   object
#  15  2012 [YR2012]  2394 non-null   object
#  16  2011 [YR2011]  2394 non-null   object
# ...

# %%
world_bank_data.describe()
# Out:
#        Country Name Country Code  \
# count          2396         2394
# unique          268          266
# top     Afghanistan          AFG
# freq              9            9
#
#                                               Series Name     Series Code  \
# count                                                2394            2394
# unique                                                  9               9
# top     Military expenditure (% of general government ...  MS.MIL.XPND.ZS
# freq                                                  266             266
#
#        2023 [YR2023] 2022 [YR2022] 2021 [YR2021] 2020 [YR2020] 2019 [YR2019]  \
# count           2394          2394          2394          2394          2394
# unique           597           712          1173          1176          1181
# top               ..            ..            ..            ..            ..
# freq            1711          1589          1110          1121          1098
#
# ...

# %%
#dropping some columns that are not needed 

world_bank_data_dropped = world_bank_data.drop(['Series Code'], axis=1)

# %%
world_bank_data_dropped.describe()
# Out:
#        Country Name Country Code  \
# count          2396         2394
# unique          268          266
# top     Afghanistan          AFG
# freq              9            9
#
#                                               Series Name 2023 [YR2023]  \
# count                                                2394          2394
# unique                                                  9           597
# top     Military expenditure (% of general government ...            ..
# freq                                                  266          1711
#
#        2022 [YR2022] 2021 [YR2021] 2020 [YR2020] 2019 [YR2019] 2018 [YR2018]  \
# count           2394          2394          2394          2394          2394
# unique           712          1173          1176          1181          1195
# top               ..            ..            ..            ..            ..
# freq            1589          1110          1121          1098          1096
#
# ...

# %%
world_bank_data_dropped = world_bank_data_dropped.rename(columns={
    "2023 [YR2023]": "2023",
    "2022 [YR2022]": "2022",
    "2021 [YR2021]": "2021",
    "2020 [YR2020]": "2020",
    "2019 [YR2019]": "2019",
    "2018 [YR2018]": "2018",
    "2017 [YR2017]": "2017",
    "2016 [YR2016]": "2016",
    "2015 [YR2015]": "2015",
    "2014 [YR2014]": "2014",
    "2013 [YR2013]": "2013",
    "2012 [YR2012]": "2012",
    "2011 [YR2011]": "2011",
    "2010 [YR2010]": "2010",
    "2009 [YR2009]": "2009",
    "2008 [YR2008]": "2008",
    "2007 [YR2007]": "2007",
    "2006 [YR2006]": "2006",
    "2005 [YR2005]": "2005",
    "2004 [YR2004]": "2004",
    "2003 [YR2003]": "2003",
    "2002 [YR2002]": "2002",
    "2001 [YR2001]": "2001",
    "2000 [YR2000]": "2000",
    "1999 [YR1999]": "1999",
    "1998 [YR1998]": "1998",
    "1997 [YR1997]": "1997",
    "1996 [YR1996]": "1996",
    "1995 [YR1995]": "1995",
    "1994 [YR1994]": "1994",
    "1993 [YR1993]": "1993",
    "1992 [YR1992]": "1992",
    "1991 [YR1991]": "1991",
    "1990 [YR1990]": "1990",
    "1989 [YR1989]": "1989",
    "1988 [YR1988]": "1988",
    "1987 [YR1987]": "1987",
    "1986 [YR1986]": "1986",
    "1985 [YR1985]": "1985",
    "1984 [YR1984]": "1984",
    "1983 [YR1983]": "1983",
    "1982 [YR1982]": "1982",
    "1981 [YR1981]": "1981",
    "1980 [YR1980]": "1980",
    "1979 [YR1979]": "1979",
    "1978 [YR1978]": "1978",
    "1977 [YR1977]": "1977",
    "1976 [YR1976]": "1976",
    "1975 [YR1975]": "1975",
    "1974 [YR1974]": "1974",
    "1973 [YR1973]": "1973",
    "1972 [YR1972]": "1972",
    "1971 [YR1971]": "1971",
    "1970 [YR1970]": "1970",
    "1969 [YR1969]": "1969",
    "1968 [YR1968]": "1968",
    "1967 [YR1967]": "1967",
    "1966 [YR1966]": "1966",
    "1965 [YR1965]": "1965",
    "1964 [YR1964]": "1964",
    "1963 [YR1963]": "1963",
    "1962 [YR1962]": "1962",
    "1961 [YR1961]": "1961",
    "1960 [YR1960]": "1960"
})

# %%
world_bank_data_dropped.describe()
# Out:
#        Country Name Country Code  \
# count          2396         2394
# unique          268          266
# top     Afghanistan          AFG
# freq              9            9
#
#                                               Series Name  2023  2022  2021  \
# count                                                2394  2394  2394  2394
# unique                                                  9   597   712  1173
# top     Military expenditure (% of general government ...    ..    ..    ..
# freq                                                  266  1711  1589  1110
#
#         2020  2019  2018  2017  ...  1969  1968  1967  1966  1965  1964  1963  \
# count   2394  2394  2394  2394  ...  2394  2394  2394  2394  2394  2394  2394
# unique  1176  1181  1195  1220  ...   285   285   279   275   272   263   253
# top       ..    ..    ..    ..  ...    ..    ..    ..    ..    ..    ..    ..
# freq    1121  1098  1096  1068  ...  2047  2048  2050  2070  2074  2060  2091
#
# ...

# %%
world_bank_data_dropped.head()
# Out:
#   Country Name Country Code  \
# 0  Afghanistan          AFG
# 1  Afghanistan          AFG
# 2  Afghanistan          AFG
# 3  Afghanistan          AFG
# 4  Afghanistan          AFG
#
#                                          Series Name 2023 2022  \
# 0  Military expenditure (% of general government ...   ..   ..
# 1                    Military expenditure (% of GDP)   ..   ..
# 2        Arms imports (SIPRI trend indicator values)   ..   ..
# 3        Arms exports (SIPRI trend indicator values)   ..   ..
# 4  Government expenditure on education, total (% ...   ..   ..
#
#                2021              2020              2019              2018  \
# 0  10.5026598533092  4.97282537449934  4.27573619654266  3.72485527466578
# 1    1.827933856217  1.35885692738929  1.17096838242129  1.00674585570556
# 2          65000000         234000000         383000000         314000000
# 3                ..                ..                ..                ..
# ...

# %%
world_bank_data_dropped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2399 entries, 0 to 2398
# Data columns (total 67 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Name  2396 non-null   object
#  1   Country Code  2394 non-null   object
#  2   Series Name   2394 non-null   object
#  3   2023          2394 non-null   object
#  4   2022          2394 non-null   object
#  5   2021          2394 non-null   object
#  6   2020          2394 non-null   object
#  7   2019          2394 non-null   object
#  8   2018          2394 non-null   object
#  9   2017          2394 non-null   object
#  10  2016          2394 non-null   object
#  11  2015          2394 non-null   object
#  12  2014          2394 non-null   object
#  13  2013          2394 non-null   object
#  14  2012          2394 non-null   object
#  15  2011          2394 non-null   object
#  16  2010          2394 non-null   object
#  17  2009          2394 non-null   object
# ...

# %%
# Assuming your dataframe is named 'df'
# First, let's extract the Afghanistan military expenditure data
afg_data = world_bank_data_dropped[world_bank_data_dropped['Country Name'] == 'Afghanistan'].iloc[0]

# Get the years and values
years = [str(year) for year in range(1960, 2024)]  # All years from 1960 to 2023
values = []

for year in years:
    if year in afg_data.index:
        val = afg_data[year]
        # Convert to float if it's a valid number, otherwise None
        if isinstance(val, str) and val.strip() == '..':
            val = None
        else:
            try:
                val = float(val) if val is not None else None
            except (ValueError, TypeError):
                val = None
    else:
        val = None
    values.append(val)
    
# Create a new dataframe for plotting
plot_data = pd.DataFrame({
    'Year': years,
    'Military Expenditure (% of govt)': values
})

# Convert Year to numeric and drop missing values
plot_data['Year'] = pd.to_numeric(plot_data['Year'])
plot_data = plot_data.dropna()

# %%
type(plot_data)
# Out:
# pandas.core.frame.DataFrame

# %%
from matplotlib.ticker import MaxNLocator

plt.figure(figsize=(12, 6))
sns.lineplot(
    data=plot_data,
    x='Year',
    y='Military Expenditure (% of govt)',
    marker='o',
    color='darkred'
)

# Force integer ticks (auto-optimized but whole numbers)
plt.gca().xaxis.set_major_locator(MaxNLocator(integer=True))

plt.title('Afghanistan Military Expenditure (% of general government expenditure)')
plt.xlabel('Year')
plt.ylabel('Percentage')
plt.grid(True, alpha=0.5)
plt.tight_layout()
plt.show()

# %%
world_bank_data_dropped.head()
# Out:
#   Country Name Country Code  \
# 0  Afghanistan          AFG
# 1  Afghanistan          AFG
# 2  Afghanistan          AFG
# 3  Afghanistan          AFG
# 4  Afghanistan          AFG
#
#                                          Series Name 2023 2022  \
# 0  Military expenditure (% of general government ...   ..   ..
# 1                    Military expenditure (% of GDP)   ..   ..
# 2        Arms imports (SIPRI trend indicator values)   ..   ..
# 3        Arms exports (SIPRI trend indicator values)   ..   ..
# 4  Government expenditure on education, total (% ...   ..   ..
#
#                2021              2020              2019              2018  \
# 0  10.5026598533092  4.97282537449934  4.27573619654266  3.72485527466578
# 1    1.827933856217  1.35885692738929  1.17096838242129  1.00674585570556
# 2          65000000         234000000         383000000         314000000
# 3                ..                ..                ..                ..
# ...

# %%
world_bank_data_dropped.describe()
# Out:
#        Country Name Country Code  \
# count          2396         2394
# unique          268          266
# top     Afghanistan          AFG
# freq              9            9
#
#                                               Series Name  2023  2022  2021  \
# count                                                2394  2394  2394  2394
# unique                                                  9   597   712  1173
# top     Military expenditure (% of general government ...    ..    ..    ..
# freq                                                  266  1711  1589  1110
#
#         2020  2019  2018  2017  ...  1969  1968  1967  1966  1965  1964  1963  \
# count   2394  2394  2394  2394  ...  2394  2394  2394  2394  2394  2394  2394
# unique  1176  1181  1195  1220  ...   285   285   279   275   272   263   253
# top       ..    ..    ..    ..  ...    ..    ..    ..    ..    ..    ..    ..
# freq    1121  1098  1096  1068  ...  2047  2048  2050  2070  2074  2060  2091
#
# ...

# %%
world_bank_data_dropped
# Out:
#                                           Country Name Country Code  \
# 0                                          Afghanistan          AFG
# 1                                          Afghanistan          AFG
# 2                                          Afghanistan          AFG
# 3                                          Afghanistan          AFG
# 4                                          Afghanistan          AFG
# ...                                                ...          ...
# 2394                                               NaN          NaN
# 2395                                               NaN          NaN
# 2396                                               NaN          NaN
# 2397  Data from database: World Development Indicators          NaN
# 2398                          Last Updated: 03/24/2025          NaN
#
#                                             Series Name 2023 2022  \
# 0     Military expenditure (% of general government ...   ..   ..
# ...

# %%
# Make a copy of the original DataFrame
df = world_bank_data_dropped.copy()

# Step 1: Replace ".." with pd.NA (Pandas' native NA value) and drop all-NA rows
df = df.replace('..', pd.NA).dropna(how='all')

# Step 2: Convert numeric columns to float
# Identify year columns (assuming they're all 4-digit numbers)
year_cols = [col for col in df.columns if isinstance(col, str) and col.isdigit() and len(col) == 4]

# Convert these columns to numeric using pd.to_numeric
for col in year_cols:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# Step 3: Drop irrelevant rows (non-country rows)
# Remove rows where Country Name contains metadata or is NA
df = df[
    df['Country Name'].notna() & 
    ~df['Country Name'].astype(str).str.contains(
        'Data from database|Last Updated', 
        na=False
    )
]

# Reset index after cleaning
df = df.reset_index(drop=True)

# Show the cleaned DataFrame
print(df.head())
print(f"\nCleaned DataFrame shape: {df.shape}")
# Out:
#   Country Name Country Code  \
# 0  Afghanistan          AFG
# 1  Afghanistan          AFG
# 2  Afghanistan          AFG
# 3  Afghanistan          AFG
# 4  Afghanistan          AFG
#
#                                          Series Name  2023  2022  \
# 0  Military expenditure (% of general government ...   NaN   NaN
# 1                    Military expenditure (% of GDP)   NaN   NaN
# 2        Arms imports (SIPRI trend indicator values)   NaN   NaN
# 3        Arms exports (SIPRI trend indicator values)   NaN   NaN
# 4  Government expenditure on education, total (% ...   NaN   NaN
#
#            2021          2020          2019          2018          2017  ...  \
# 0  1.050266e+01  4.972825e+00  4.275736e+00  3.724855e+00  3.652592e+00  ...
# 1  1.827934e+00  1.358857e+00  1.170968e+00  1.006746e+00  9.452268e-01  ...
# 2  6.500000e+07  2.340000e+08  3.830000e+08  3.140000e+08  2.360000e+08  ...
# 3           NaN           NaN           NaN           NaN           NaN  ...
# ...

# %%
df.dtypes
# Out:
# Country Name     object
# Country Code     object
# Series Name      object
# 2023            float64
# 2022            float64
#                  ...
# 1964            float64
# 1963            float64
# 1962            float64
# 1961            float64
# 1960            float64
# Length: 67, dtype: object

# %%
import pandas as pd
import os
from natsort import os_sorted
from datetime import datetime, timedelta
import requests
import zipfile
import warnings 
import urllib3

from dotenv import dotenv_values
from sqlalchemy import create_engine, types, text

# we'll suppress the "missing SSL certificate" warnings while downloading files
warnings.simplefilter("ignore", urllib3.exceptions.InsecureRequestWarning)

# %%
# create folder 'data'
os.makedirs('./cleandata', exist_ok=True)

# %%
# saving
df.to_csv(f'./cleandata/worldbank_cleaned.csv', index=False)

print(f'✅Combined Dataset Saved: worldbank_cleaned.csv', end=' ')

# assessing the size of the extracted file
file_size = os.path.getsize(f'./cleandata/worldbank_cleaned.csv') 
size_in_mb = file_size / (1024 ** 2) 
print(f"({size_in_mb:.2f} MB)\n")

# Get the absolute path
absolute_path = os.path.abspath(f'./data/worldbank_cleaned.csv')
print(absolute_path)
# Out:
# ✅Combined Dataset Saved: worldbank_cleaned.csv (0.87 MB)
#
# c:\Users\askha\Desktop\SpicedAcademy\arms_and_aid\Askhat\data\worldbank_cleaned.csv

# %% [markdown]
# ### We got the data in a dataframe. Now it needs to be loaded into our DB.

# %%
# we will need the credentials we saved in the .env file
from dotenv import dotenv_values

# We also will need SQLAlchemy and its functions
from sqlalchemy import create_engine, types
from sqlalchemy.dialects.postgresql import JSON as postgres_json

import pandas as pd

# with 'datetime' we want to catch the timestamp of the API call. For the actuality reference. 
# and 'time' for slowing down a .bit
from datetime import datetime
import time

# %%
# getting API and DB credentials - Alternative 1: dotenv_values()

config = dotenv_values()
 
pg_user = config['POSTGRES_USER'] # align the key labels with your .env file
pg_host = config['POSTGRES_HOST']
pg_port = config['POSTGRES_PORT']
pg_db = config['POSTGRES_DB']
pg_schema = config['POSTGRES_SCHEMA']
pg_pass = config['POSTGRES_PASS']

# %%
pg_schema
# Out:
# 'war_and_peace'

# %%
pg_db
# Out:
# 'lavender_notebooks'

# %%
# updating the url
url = f'postgresql://{pg_user}:{pg_pass}@{pg_host}:{pg_port}/{pg_db}'

# creating the engine
engine = create_engine(url, echo=False)

# %%
engine.url # checking the url (pass is hidden)
# Out:
# postgresql://askhatbolatkhan:***@data-analytics-course-2.c8g8r1deus2v.eu-central-1.rds.amazonaws.com:5432/lavender_notebooks

# %%
## add code here...
worldbank_cleaned= pd.read_csv(f'./cleandata/worldbank_cleaned.csv')
worldbank_cleaned.head()
# Out:
#   Country Name Country Code  \
# 0  Afghanistan          AFG
# 1  Afghanistan          AFG
# 2  Afghanistan          AFG
# 3  Afghanistan          AFG
# 4  Afghanistan          AFG
#
#                                          Series Name  2023  2022  \
# 0  Military expenditure (% of general government ...   NaN   NaN
# 1                    Military expenditure (% of GDP)   NaN   NaN
# 2        Arms imports (SIPRI trend indicator values)   NaN   NaN
# 3        Arms exports (SIPRI trend indicator values)   NaN   NaN
# 4  Government expenditure on education, total (% ...   NaN   NaN
#
#            2021          2020          2019          2018          2017  ...  \
# 0  1.050266e+01  4.972825e+00  4.275736e+00  3.724855e+00  3.652592e+00  ...
# 1  1.827934e+00  1.358857e+00  1.170968e+00  1.006746e+00  9.452268e-01  ...
# 2  6.500000e+07  2.340000e+08  3.830000e+08  3.140000e+08  2.360000e+08  ...
# 3           NaN           NaN           NaN           NaN           NaN  ...
# ...

# %%
worldbank_cleaned.dtypes
# Out:
# Country Name     object
# Country Code     object
# Series Name      object
# 2023            float64
# 2022            float64
#                  ...
# 1964            float64
# 1963            float64
# 1962            float64
# 1961            float64
# 1960            float64
# Length: 67, dtype: object

# %%
# defining data types for the DB
worldbank_dtypes = {
    'Country Name ': types.String,
    'Country Code': types.String,
    'Series Name': types.String,
    **{str(year): types.Float() for year in range(1960, 2024)}
}

# %%
pg_schema
# Out:
# 'war_and_peace'

# %%
# writing dataframe to DB
worldbank_cleaned.to_sql(name = 'worldbank_cleaned_new', 
                       con = engine, 
                       schema = pg_schema, # pandas is allowing to specify, in which schema the table shall be created
                       if_exists='replace', 
                       dtype=worldbank_dtypes,
                       index=False
                      )
# Out:
# 442
